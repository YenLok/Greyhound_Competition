# %%
import numpy as np
import pandas as pd
import feather
import os, sys, random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None) # to ensure console display all columns
pd.set_option('display.float_format', '{:0.3f}'.format)
pd.set_option('display.max_row', 50)
plt.style.use('ggplot')
from pathlib import Path

project = 'Greyhound_Competition'
projectPath = Path(r'E:/Projects') / f"{project}"
os.chdir(projectPath)
sys.path.append(str(projectPath))

dataPath = projectPath / 'data'
pickleDataPath = dataPath / 'pickle'
htmlDataPath = dataPath / 'html'
imageDataPath = dataPath / 'image'
dataInputPath = dataPath / 'input'
dataWorkingPath = dataPath / 'working'
dataOutputPath = dataPath / 'output'
modelPath = projectPath / 'models'

import pickle
def save_obj(obj, name):
    with open(pickleDataPath / f'{name}.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(pickleDataPath / f'{name}.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# Imports

# %%
import tensorflow as tf
print(tf.__version__)

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, concatenate
from tensorflow.keras import layers, optimizers, losses, metrics, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

def set_seed(seed):
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
# Out:
# 2.9.1

# %% [markdown]
# Settings

# %%
col_feature = [str(x) for x in list(range(62))]
N = len(col_feature)
n_traps = 6
input_file = f"upwork_data2.csv"

# %% [markdown]
# Train Model

# %%
df = pd.read_csv(dataInputPath / input_file)
df = df[df.trap <= 6]

def group_horse_and_result(element):
    if element[0] == 'finish':
        return 100 + element[1] # to make sure finish resuls are put near the end
    else:
        return element[1]

df = df.pivot(index = 'race_id', columns = 'trap', values = df.columns[2:])
rearranged_columns = sorted(list(df.columns.values), key = group_horse_and_result)
df = df[rearranged_columns]
df.dropna(inplace = True)
X = df[df.columns[:-6]]
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X),columns = X.columns)
y_won = df[df.columns[-6:]].applymap(lambda x: 1 if x == 1 else 0)
X_train, X_test, y_train, y_test = train_test_split(X, y_won, train_size=0.8, test_size=0.2, random_state=1)
train_id_list = list(y_train.index)
test_id_list = list(y_test.index)
train_df = df.loc[train_id_list]
test_df = df.loc[test_id_list]


## The generally good architecture based on the observations from the top architectures with the best results obtained from develop.py
set_seed(1)
act = 'relu'

def get_MLP_input_layer(N, act):
    input = Input(shape=(N,))

    x = Dense(32, activation=act)(input)
    x = Dropout(0.2)(x)

    x = Dense(32, activation=act)(x)
    x = Dropout(0.2)(x)

    x = Dense(16, activation=act)(x)
    #x = Dropout(0.2)(x)

    x = Model(inputs=input, outputs=x)

    return x

concat_list = []
for i in range(n_traps):
    concat_list += [get_MLP_input_layer(N, act)]

combined = concatenate([x.output for x in concat_list])

m = Dense(32, activation=act)(combined)
#m = BatchNormalization()(m)

m = Dense(32, activation=act)(m)
m = BatchNormalization()(m)

m = Dense(n_traps, activation="softmax")(m)
model = Model(inputs=[x.input for x in concat_list], outputs=m)

model.compile(
    optimizer=tf.keras.optimizers.Adam(lr=0.005),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['acc', tf.keras.metrics.Precision(name='precision')],
)

early_stop = EarlyStopping(monitor='val_acc', min_delta=0,
                           patience=50, verbose=0, mode='auto',
                           baseline=0, restore_best_weights=True)

history = model.fit([train_df.xs(i, level="trap", axis=1)[col_feature].values for i in range(1, n_traps+1)],
                    y_won.loc[train_id_list].values,
                    epochs=1000,
                    batch_size=1028,
                    validation_data=([test_df.xs(i, level="trap", axis=1)[col_feature].values for i in range(1, n_traps+1)],
                                     y_won.loc[test_id_list].values),
                    shuffle=True, verbose=1,
                    callbacks=[early_stop])

test_loss, test_acc, test_precision = model.evaluate([test_df.xs(i, level="trap", axis=1)[col_feature].values for i in range(1, n_traps+1)],
                                                     y_won.loc[test_id_list].values,
                                                     batch_size=1028,
                                                     verbose=0)
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 4s 90ms/step - loss: 1.9843 - acc: 0.1710 - precision: 0.1840 - val_loss: 2.2729 - val_acc: 0.1768 - val_precision: 0.1481
# Epoch 2/1000
# 15/15 [==============================] - 0s 30ms/step - loss: 1.8197 - acc: 0.1677 - precision: 0.2000 - val_loss: 1.8605 - val_acc: 0.1708 - val_precision: 0.0000e+00
# Epoch 3/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.8038 - acc: 0.1717 - precision: 0.0000e+00 - val_loss: 1.8583 - val_acc: 0.1755 - val_precision: 0.0000e+00
# Epoch 4/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.8012 - acc: 0.1720 - precision: 0.0000e+00 - val_loss: 1.8452 - val_acc: 0.1642 - val_precision: 0.0000e+00
# Epoch 5/1000
# 15/15 [==============================] - 0s 29ms/step - loss: 1.8005 - acc: 0.1703 - precision: 0.0000e+00 - val_loss: 1.8110 - val_acc: 0.1736 - val_precision: 0.0000e+00
# Epoch 6/1000
# 15/15 [==============================] - 0s 29ms/step - loss: 1.7997 - acc: 0.1758 - precision: 0.0000e+00 - val_loss: 1.8067 - val_acc: 0.1734 - val_precision: 0.0000e+00
# Epoch 7/1000
# 15/15 [==============================] - 0s 29ms/step - loss: 1.7998 - acc: 0.1743 - precision: 0.0000e+00 - val_loss: 1.8274 - val_acc: 0.1689 - val_precision: 0.0000e+00
# Epoch 8/1000
# 15/15 [==============================] - 0s 30ms/step - loss: 1.8004 - acc: 0.1670 - precision: 0.0000e+00 - val_loss: 1.8061 - val_acc: 0.1731 - val_precision: 0.0000e+00
# Epoch 9/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.8013 - acc: 0.1726 - precision: 0.0000e+00 - val_loss: 1.8216 - val_acc: 0.1736 - val_precision: 0.0000e+00
# Epoch 10/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.8004 - acc: 0.1698 - precision: 0.0000e+00 - val_loss: 1.8005 - val_acc: 0.1702 - val_precision: 0.0000e+00
# Epoch 11/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7989 - acc: 0.1686 - precision: 0.0000e+00 - val_loss: 1.8070 - val_acc: 0.1692 - val_precision: 0.0000e+00
# Epoch 12/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7996 - acc: 0.1686 - precision: 0.0000e+00 - val_loss: 1.8072 - val_acc: 0.1770 - val_precision: 0.0000e+00
# Epoch 13/1000
# 15/15 [==============================] - 0s 29ms/step - loss: 1.7993 - acc: 0.1738 - precision: 0.0000e+00 - val_loss: 1.8061 - val_acc: 0.1692 - val_precision: 0.0000e+00
1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7595 - acc: 0.2305 - precision: 0.6000 - val_loss: 1.7925 - val_acc: 0.1919 - val_precision: 0.0000e+00
# Epoch 136/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7652 - acc: 0.2246 - precision: 0.5741 - val_loss: 1.7773 - val_acc: 0.2178 - val_precision: 0.3333
# Epoch 137/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 1.7754 - acc: 0.2112 - precision: 0.5000 - val_loss: 1.8040 - val_acc: 0.1982 - val_precision: 0.0000e+00
# Epoch 138/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7769 - acc: 0.2121 - precision: 0.4167 - val_loss: 1.7848 - val_acc: 0.2092 - val_precision: 0.0000e+00
# Epoch 139/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7704 - acc: 0.2185 - precision: 0.6538 - val_loss: 1.7844 - val_acc: 0.1993 - val_precision: 0.0000e+00
# Epoch 140/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7692 - acc: 0.2202 - precision: 0.4603 - val_loss: 1.7801 - val_acc: 0.2126 - val_precision: 0.1429
# Epoch 141/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 1.7674 - acc: 0.2229 - precision: 0.5652 - val_loss: 1.7824 - val_acc: 0.2019 - val_precision: 0.0000e+00
# Epoch 142/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7699 - acc: 0.2221 - precision: 0.4634 - val_loss: 1.8186 - val_acc: 0.1846 - val_precision: 0.3125
# Epoch 143/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7850 - acc: 0.2079 - precision: 0.4706 - val_loss: 1.9587 - val_acc: 0.1522 - val_precision: 0.3182
# Epoch 144/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7855 - acc: 0.2072 - precision: 0.3902 - val_loss: 1.7915 - val_acc: 0.2011 - val_precision: 0.0000e+00
# Epoch 145/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7745 - acc: 0.2188 - precision: 0.4872 - val_loss: 1.8085 - val_acc: 0.2027 - val_precision: 0.3125
# Epoch 146/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7812 - acc: 0.2080 - precision: 0.6786 - val_loss: 1.8124 - val_acc: 0.1959 - val_precision: 0.2500
# Epoch 147/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7797 - acc: 0.2111 - precision: 0.7500 - val_loss: 1.7901 - val_acc: 0.2252 - val_precision: 0.2500
# Epoch 148/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7756 - acc: 0.2198 - precision: 0.4651 - val_loss: 1.7909 - val_acc: 0.2147 - val_precision: 0.1667
# Epoch 149/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7722 - acc: 0.2131 - precision: 0.6000 - val_loss: 1.7901 - val_acc: 0.1998 - val_precision: 0.3333
# Epoch 150/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7784 - acc: 0.2089 - precision: 0.4444 - val_loss: 1.8039 - val_acc: 0.2003 - val_precision: 0.2500
# Epoch 151/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 1.7852 - acc: 0.2070 - precision: 0.5625 - val_loss: 1.7921 - val_acc: 0.2027 - val_precision: 0.0000e+00
# Epoch 152/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 1.7920 - acc: 0.1942 - precision: 0.4762 - val_loss: 1.9282 - val_acc: 0.1778 - val_precision: 0.0000e+00
# Accuracy: 0.227, Precision: 0.250

# %%
print(f"Accuracy: {test_acc:,.3f}, Precision: {test_precision:,.3f}")
# Out:
# Accuracy: 0.227, Precision: 0.250
